# %%
from bs4 import BeautifulSoup
import requests, json
from splinter import Browser

# %%
#https://www.fandango.com/44107_movietimes?mode=general&q=44107&date=2019-01-20
zipcode = "44107"
movie_date = "2019-01-22"
url = ("https://www.fandango.com/44107_movietimes?mode=general&q={0}&date={1}").format(zipcode, movie_date)
print(url)
# Out:
# https://www.fandango.com/44107_movietimes?mode=general&q=44107&date=2019-01-22

# %%
executable_path = {'executable_path': 'static/webdriver/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
browser.visit(url)
# HTML object
html = browser.html
# Parse HTML with Beautiful Soup
soup = BeautifulSoup(html, 'lxml')

# %%
#page_response = requests.get(url, timeout=5)
# here, we fetch the content from the url, using the requests library
#soup = BeautifulSoup(page_response.content, "lxml")
#we use the html parser to parse the url content and store it in a variable.

# %%
showtimes = soup.find('div',class_='fd-showtimes')

# %%
theaters = showtimes.find_all('li', class_='fd-theater')

# %%
#create empty dictionary
theater_data = []
#Find theater_names, theater locations, movies, and showtimes.
theater_names = []
theater_locations = []
theaters_movies = []
for i in range(0,len(theaters)):
    theater_name = theaters[i].find('a',class_='light').text
    theater_names.append(theater_name)
    theaterlocation = theaters[i].find('div',class_='fd-theater__address-wrap').text
    theater_location = ' '.join(theaterlocation.rstrip().split())
    theater_locations.append(theater_location)
    movies = theaters[i].find_all('li',class_='fd-movie')
    theater_movies = []
    movies_titles = []
    movies_showtimes = []
    movies_posters = []
    for k in range(0,len(movies)):
        if movies[k].find('a',class_='dark'):
            movie_title = movies[k].find('a',class_='dark').text
        else:
            movie_title = movies[k].find('a',class_='dark')
        movies_titles.append(movie_title)
        if movies[k].find('img'):
            movie_poster = movies[k].find('img')['src']
        else:
            movie_poster = movies[k].find('img')
        movies_posters.append(movie_poster)
        movie_showtimes = []
        numshows=movies[k].find_all('a',class_='showtime-btn--available')
        for j in range(0,len(numshows)):
            showtime = numshows[j].text
            movie_showtimes.append(showtime)
        movies_showtimes.append(movie_showtimes)
        theater_movies.append({'Title':movies_titles[k],'Showtimes':movies_showtimes[k],'Poster_URL':movies_posters[k]})
    theaters_movies.append(theater_movies)
    theater_data.append({'Name':theater_names[i], 'Address':theater_locations[i],'Movies':theaters_movies[i]})

# %%
len(theaters_movies)
# Out:
# 10

# %%
len(theater_data)
# Out:
# 10

# %%
theaters_movies[0]
# Out:
# [{'Title': 'Glass (2019)',
#   'Showtimes': ['1:00p', '4:00p', '6:50p', '9:45p'],
#   'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg'},
#  {'Title': "A Dog's Way Home",
#   'Showtimes': ['1:45p', '4:15p', '7:00p', '10:00p'],
#   'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg'},
#  {'Title': 'On the Basis of Sex',
#   'Showtimes': ['1:15p', '4:15p', '7:00p', '9:50p'],
#   'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg'},
#  {'Title': 'Aquaman',
#   'Showtimes': ['12:30p', '3:40p', '6:40p', '9:40p'],
#   'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg'},
#  {'Title': 'Mary Poppins Returns (2018)',
#   'Showtimes': ['12:45p', '3:45p', '6:45p', '9:50p'],
#   'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg'},
#  {'Title': 'Spider-Man: Into the Spider-Verse',
#   'Showtimes': ['1:30p', '4:30p', '7:20p', '9:30p'],
#   'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg'}]

# %%
theater_data[0]['Movies'][0]['Title']
# Out:
# 'Glass (2019)'

# %%
theater_data[0]
# Out:
# {'Name': 'AMC Westwood Town Center 6',
#  'Address': '21653 Center Ridge Rd., Rocky River, OH 44116',
#  'Movies': [{'Title': 'Glass (2019)',
#    'Showtimes': ['1:00p', '4:00p', '6:50p', '9:45p'],
#    'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg'},
#   {'Title': "A Dog's Way Home",
#    'Showtimes': ['1:45p', '4:15p', '7:00p', '10:00p'],
#    'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg'},
#   {'Title': 'On the Basis of Sex',
#    'Showtimes': ['1:15p', '4:15p', '7:00p', '9:50p'],
#    'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg'},
#   {'Title': 'Aquaman',
#    'Showtimes': ['12:30p', '3:40p', '6:40p', '9:40p'],
#    'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg'},
#   {'Title': 'Mary Poppins Returns (2018)',
#    'Showtimes': ['12:45p', '3:45p', '6:45p', '9:50p'],
#    'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg'},
#   {'Title': 'Spider-Man: Into the Spider-Verse',
#    'Showtimes': ['1:30p', '4:30p', '7:20p', '9:30p'],
#    'Poster_URL': '//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg'}]}

# %%
print(json.dumps(theater_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "Address": "21653 Center Ridge Rd., Rocky River, OH 44116",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [
#                     "1:00p",
#                     "4:00p",
#                     "6:50p",
#                     "9:45p"
#                 ],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg",
#                 "Showtimes": [
#                     "1:45p",
#                     "4:15p",
#                     "7:00p",
#                     "10:00p"
#                 ],
#                 "Title": "A Dog's Way Home"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg",
#                 "Showtimes": [
#                     "1:15p",
#                     "4:15p",
#                     "7:00p",
#                     "9:50p"
#                 ],
#                 "Title": "On the Basis of Sex"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "12:30p",
#                     "3:40p",
#                     "6:40p",
#                     "9:40p"
#                 ],
#                 "Title": "Aquaman"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg",
#                 "Showtimes": [
#                     "12:45p",
#                     "3:45p",
#                     "6:45p",
#                     "9:50p"
#                 ],
#                 "Title": "Mary Poppins Returns (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [
#                     "1:30p",
#                     "4:30p",
#                     "7:20p",
#                     "9:30p"
#                 ],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             }
#         ],
#         "Name": "AMC Westwood Town Center 6"
#     },
#     {
#         "Address": "4788 Ridge Road, Brooklyn, OH 44144",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [
#                     "10:00a",
#                     "10:10a",
#                     "11:00a",
#                     "12:15p",
#                     "1:00p",
#                     "3:20p",
#                     "4:00p",
#                     "6:30p",
#                     "7:00p",
#                     "9:30p",
#                     "10:00p",
#                     "7:05p"
#                 ],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213339/IfBealeStreetCouldTalk2018.jpg",
#                 "Showtimes": [
#                     "4:20p",
#                     "9:55p"
#                 ],
#                 "Title": "If Beale Street Could Talk"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214774/TheUpside2018.jpg",
#                 "Showtimes": [
#                     "12:50p",
#                     "3:45p",
#                     "6:45p",
#                     "9:45p"
#                 ],
#                 "Title": "The Upside"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215085/EscapeRoom2019.jpg",
#                 "Showtimes": [
#                     "2:00p",
#                     "4:40p",
#                     "7:25p",
#                     "10:10p"
#                 ],
#                 "Title": "Escape Room (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "3:30p",
#                     "9:50p",
#                     "10:15a",
#                     "12:20p",
#                     "6:40p"
#                 ],
#                 "Title": "Aquaman"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208500/BB_Online_Dom_Payoff_1-Sheet_H-Steinfeld_BB_Bridge_Autobot.jpg",
#                 "Showtimes": [
#                     "1:25p",
#                     "4:15p",
#                     "10:05p"
#                 ],
#                 "Title": "Bumblebee"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [
#                     "10:20a",
#                     "1:15p",
#                     "4:05p",
#                     "6:50p",
#                     "9:40p"
#                 ],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214756/MULE_VERT_MAIN_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "1:30p",
#                     "7:10p"
#                 ],
#                 "Title": "The Mule (2018)"
#             }
#         ],
#         "Name": "AMC Ridge Park Square 8"
#     },
#     {
#         "Address": "30147 Detroit Road, Westlake, OH 44145",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [
#                     "1:30p",
#                     "4:30p",
#                     "7:30p",
#                     "10:30p",
#                     "12:30p",
#                     "3:30p",
#                     "6:30p",
#                     "9:30p"
#                 ],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215170/dragonballzsuper-broly-400x600.jpg",
#                 "Showtimes": [
#                     "12:00p",
#                     "2:30p",
#                     "5:00p",
#                     "7:30p",
#                     "10:00p"
#                 ],
#                 "Title": "Dragon Ball Super: Broly"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg",
#                 "Showtimes": [
#                     "12:10p",
#                     "2:40p",
#                     "5:10p",
#                     "7:40p",
#                     "10:10p"
#                 ],
#                 "Title": "A Dog's Way Home"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213339/IfBealeStreetCouldTalk2018.jpg",
#                 "Showtimes": [
#                     "12:00p",
#                     "3:00p",
#                     "6:00p",
#                     "8:50p"
#                 ],
#                 "Title": "If Beale Street Could Talk"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg",
#                 "Showtimes": [
#                     "12:50p",
#                     "3:50p",
#                     "6:40p",
#                     "9:40p"
#                 ],
#                 "Title": "On the Basis of Sex"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/206497/Replicas2019.jpg",
#                 "Showtimes": [
#                     "7:00p",
#                     "10:00p"
#                 ],
#                 "Title": "Replicas"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214774/TheUpside2018.jpg",
#                 "Showtimes": [
#                     "1:10p",
#                     "4:20p",
#                     "7:20p",
#                     "10:20p"
#                 ],
#                 "Title": "The Upside"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215085/EscapeRoom2019.jpg",
#                 "Showtimes": [
#                     "12:20p",
#                     "2:50p",
#                     "5:20p",
#                     "7:50p",
#                     "10:20p"
#                 ],
#                 "Title": "Escape Room (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214614/Vice2018.jpg",
#                 "Showtimes": [
#                     "12:10p",
#                     "3:10p",
#                     "6:10p",
#                     "9:20p"
#                 ],
#                 "Title": "Vice (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "12:30p",
#                     "3:40p",
#                     "6:50p",
#                     "10:00p"
#                 ],
#                 "Title": "Aquaman"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208500/BB_Online_Dom_Payoff_1-Sheet_H-Steinfeld_BB_Bridge_Autobot.jpg",
#                 "Showtimes": [
#                     "1:20p",
#                     "4:10p",
#                     "7:00p",
#                     "9:50p"
#                 ],
#                 "Title": "Bumblebee"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/211485/MQOS_OneSheet.jpg",
#                 "Showtimes": [
#                     "3:30p"
#                 ],
#                 "Title": "Mary Queen of Scots (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/211517/SecondAct_27x40_1Sheet_RGB.jpg",
#                 "Showtimes": [
#                     "12:40p"
#                 ],
#                 "Title": "Second Act"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg",
#                 "Showtimes": [
#                     "1:00p",
#                     "4:10p",
#                     "7:10p",
#                     "10:10p"
#                 ],
#                 "Title": "Mary Poppins Returns (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [
#                     "1:40p",
#                     "4:40p",
#                     "7:30p",
#                     "10:30p"
#                 ],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212924/TheFavourite2018.jpg",
#                 "Showtimes": [
#                     "6:30p",
#                     "9:20p"
#                 ],
#                 "Title": "The Favourite"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214756/MULE_VERT_MAIN_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "1:00p",
#                     "3:40p",
#                     "6:20p",
#                     "9:00p"
#                 ],
#                 "Title": "The Mule (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/201129/WIR2_Payoff_195_B_NT_v70_A_Mech5_FS.jpg",
#                 "Showtimes": [
#                     "12:40p",
#                     "3:20p"
#                 ],
#                 "Title": "Ralph Breaks the Internet"
#             }
#         ],
#         "Name": "Regal Crocker Park Stadium 16 & IMAX"
#     },
#     {
#         "Address": "450 Great Northern Mall, North Olmsted, OH 44070",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [
#                     "1:00p",
#                     "4:00p",
#                     "7:00p",
#                     "10:15p",
#                     "12:00p",
#                     "3:00p",
#                     "6:15p",
#                     "9:15p"
#                 ],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg",
#                 "Showtimes": [
#                     "12:00p",
#                     "2:30p",
#                     "5:00p",
#                     "6:50p",
#                     "9:20p"
#                 ],
#                 "Title": "A Dog's Way Home"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214774/TheUpside2018.jpg",
#                 "Showtimes": [
#                     "12:30p",
#                     "3:30p",
#                     "6:40p",
#                     "9:45p"
#                 ],
#                 "Title": "The Upside"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215085/EscapeRoom2019.jpg",
#                 "Showtimes": [
#                     "12:20p",
#                     "2:50p",
#                     "5:30p",
#                     "8:00p",
#                     "10:30p"
#                 ],
#                 "Title": "Escape Room (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "12:50p",
#                     "4:20p",
#                     "7:25p",
#                     "9:30p"
#                 ],
#                 "Title": "Aquaman"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208500/BB_Online_Dom_Payoff_1-Sheet_H-Steinfeld_BB_Bridge_Autobot.jpg",
#                 "Showtimes": [
#                     "1:20p",
#                     "4:15p",
#                     "7:30p",
#                     "10:10p"
#                 ],
#                 "Title": "Bumblebee"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg",
#                 "Showtimes": [
#                     "12:15p",
#                     "3:10p",
#                     "6:20p",
#                     "9:40p"
#                 ],
#                 "Title": "Mary Poppins Returns (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [
#                     "1:15p",
#                     "4:00p",
#                     "6:45p",
#                     "10:30p"
#                 ],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214756/MULE_VERT_MAIN_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "1:30p",
#                     "4:30p",
#                     "7:10p",
#                     "9:50p"
#                 ],
#                 "Title": "The Mule (2018)"
#             }
#         ],
#         "Name": "Regal Great Northern Mall Stadium 10 & RPX (Ohio)"
#     },
#     {
#         "Address": "18348 Bagley Road, Middleburg Heights, OH 44130",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [
#                     "12:15p",
#                     "1:20p",
#                     "3:20p",
#                     "4:20p",
#                     "6:20p",
#                     "7:20p",
#                     "9:20p",
#                     "10:20p"
#                 ],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg",
#                 "Showtimes": [
#                     "1:10p",
#                     "4:05p",
#                     "6:30p",
#                     "9:10p"
#                 ],
#                 "Title": "A Dog's Way Home"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg",
#                 "Showtimes": [
#                     "12:45p",
#                     "3:35p",
#                     "6:45p",
#                     "9:40p"
#                 ],
#                 "Title": "On the Basis of Sex"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/206497/Replicas2019.jpg",
#                 "Showtimes": [
#                     "1:15p"
#                 ],
#                 "Title": "Replicas"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214774/TheUpside2018.jpg",
#                 "Showtimes": [
#                     "1:05p",
#                     "4:10p",
#                     "7:10p",
#                     "10:10p"
#                 ],
#                 "Title": "The Upside"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215085/EscapeRoom2019.jpg",
#                 "Showtimes": [
#                     "1:40p",
#                     "4:40p",
#                     "8:00p",
#                     "10:40p"
#                 ],
#                 "Title": "Escape Room (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214614/Vice2018.jpg",
#                 "Showtimes": [
#                     "12:25p",
#                     "3:40p",
#                     "7:00p",
#                     "10:00p"
#                 ],
#                 "Title": "Vice (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "12:35p",
#                     "3:45p",
#                     "6:55p",
#                     "10:05p"
#                 ],
#                 "Title": "Aquaman"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208500/BB_Online_Dom_Payoff_1-Sheet_H-Steinfeld_BB_Bridge_Autobot.jpg",
#                 "Showtimes": [
#                     "1:45p",
#                     "4:30p",
#                     "7:30p",
#                     "10:35p"
#                 ],
#                 "Title": "Bumblebee"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg",
#                 "Showtimes": [
#                     "12:15p",
#                     "3:15p",
#                     "6:35p",
#                     "9:30p"
#                 ],
#                 "Title": "Mary Poppins Returns (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [
#                     "1:30p",
#                     "4:15p",
#                     "7:45p",
#                     "10:30p"
#                 ],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214756/MULE_VERT_MAIN_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "12:50p",
#                     "3:50p",
#                     "6:50p",
#                     "9:55p"
#                 ],
#                 "Title": "The Mule (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/201129/WIR2_Payoff_195_B_NT_v70_A_Mech5_FS.jpg",
#                 "Showtimes": [
#                     "12:20p",
#                     "3:00p",
#                     "5:45p",
#                     "9:00p"
#                 ],
#                 "Title": "Ralph Breaks the Internet"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213524/GreenBook2018.jpg",
#                 "Showtimes": [
#                     "12:30p",
#                     "3:30p",
#                     "6:40p",
#                     "9:45p"
#                 ],
#                 "Title": "Green Book"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/211850/BoRhap_1Sht_VerB_View.jpg",
#                 "Showtimes": [
#                     "1:00p",
#                     "4:00p",
#                     "7:15p",
#                     "10:25p"
#                 ],
#                 "Title": "Bohemian Rhapsody"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208383/astarisborn-posterart.jpg",
#                 "Showtimes": [
#                     "3:55p",
#                     "7:05p",
#                     "10:15p"
#                 ],
#                 "Title": "A Star Is Born (2018)"
#             }
#         ],
#         "Name": "Regal Middleburg Town Square Stadium 16"
#     },
#     {
#         "Address": "11610 Euclid Ave., Cleveland, OH 44106",
#         "Movies": [
#             {
#                 "Poster_URL": null,
#                 "Showtimes": [],
#                 "Title": null
#             }
#         ],
#         "Name": "Cleveland Institute of Art Cinematheque"
#     },
#     {
#         "Address": "6001 Canal Road, Valley View, OH 44125",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/209491/CanalStreet_KeyArt_40sm.jpg",
#                 "Showtimes": [
#                     "12:50p",
#                     "4:15p",
#                     "7:15p",
#                     "10:15p"
#                 ],
#                 "Title": "Canal Street"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [
#                     "11:25a",
#                     "12:00p",
#                     "12:45p",
#                     "2:25p",
#                     "3:05p",
#                     "3:50p",
#                     "5:25p",
#                     "6:05p",
#                     "7:00p",
#                     "8:25p",
#                     "9:10p",
#                     "10:05p",
#                     "10:45a",
#                     "1:45p",
#                     "4:45p",
#                     "7:45p",
#                     "10:45p"
#                 ],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215170/dragonballzsuper-broly-400x600.jpg",
#                 "Showtimes": [
#                     "11:15a",
#                     "12:30p",
#                     "1:50p",
#                     "3:05p",
#                     "4:25p",
#                     "5:35p",
#                     "7:00p",
#                     "8:10p",
#                     "9:35p",
#                     "10:40p"
#                 ],
#                 "Title": "Dragon Ball Super: Broly"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg",
#                 "Showtimes": [
#                     "10:55a",
#                     "1:25p",
#                     "3:55p",
#                     "7:35p",
#                     "10:05p"
#                 ],
#                 "Title": "A Dog's Way Home"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213339/IfBealeStreetCouldTalk2018.jpg",
#                 "Showtimes": [
#                     "12:50p",
#                     "3:45p",
#                     "6:55p",
#                     "9:45p"
#                 ],
#                 "Title": "If Beale Street Could Talk"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg",
#                 "Showtimes": [
#                     "11:00a",
#                     "1:50p",
#                     "4:40p",
#                     "7:30p",
#                     "10:20p"
#                 ],
#                 "Title": "On the Basis of Sex"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/206497/Replicas2019.jpg",
#                 "Showtimes": [
#                     "2:05p",
#                     "4:55p"
#                 ],
#                 "Title": "Replicas"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214774/TheUpside2018.jpg",
#                 "Showtimes": [
#                     "11:55a",
#                     "2:55p",
#                     "6:45p",
#                     "9:55p"
#                 ],
#                 "Title": "The Upside"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/216116/URI-POSTER-Open-Digital.jpg",
#                 "Showtimes": [
#                     "8:15p"
#                 ],
#                 "Title": "Uri"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/216458/PettaRenFan.jpg",
#                 "Showtimes": [
#                     "10:45a",
#                     "2:30p",
#                     "6:15p",
#                     "10:00p"
#                 ],
#                 "Title": "Petta"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215085/EscapeRoom2019.jpg",
#                 "Showtimes": [
#                     "10:50a",
#                     "1:30p",
#                     "4:05p",
#                     "6:35p",
#                     "10:10p"
#                 ],
#                 "Title": "Escape Room (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214614/Vice2018.jpg",
#                 "Showtimes": [
#                     "12:35p",
#                     "4:10p",
#                     "7:15p",
#                     "10:25p"
#                 ],
#                 "Title": "Vice (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208499/AQAMN_VERT_MAIN_DUO_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "11:00a",
#                     "12:40p",
#                     "2:20p",
#                     "4:00p",
#                     "5:40p",
#                     "7:20p",
#                     "9:00p",
#                     "10:35p"
#                 ],
#                 "Title": "Aquaman"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208500/BB_Online_Dom_Payoff_1-Sheet_H-Steinfeld_BB_Bridge_Autobot.jpg",
#                 "Showtimes": [
#                     "11:45a",
#                     "2:45p",
#                     "5:50p",
#                     "8:50p"
#                 ],
#                 "Title": "Bumblebee"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/211517/SecondAct_27x40_1Sheet_RGB.jpg",
#                 "Showtimes": [
#                     "11:20a"
#                 ],
#                 "Title": "Second Act"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/203803/MPR-Payoff_1-Sheet_v8a_Sm.jpg",
#                 "Showtimes": [
#                     "11:05a",
#                     "2:10p",
#                     "6:10p",
#                     "9:15p"
#                 ],
#                 "Title": "Mary Poppins Returns (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [
#                     "11:10a",
#                     "2:00p",
#                     "4:50p",
#                     "7:40p",
#                     "10:30p"
#                 ],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212924/TheFavourite2018.jpg",
#                 "Showtimes": [
#                     "11:50a",
#                     "6:30p"
#                 ],
#                 "Title": "The Favourite"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214756/MULE_VERT_MAIN_DOM_2764x4096_master.jpg",
#                 "Showtimes": [
#                     "11:40a",
#                     "2:40p",
#                     "6:20p",
#                     "9:25p"
#                 ],
#                 "Title": "The Mule (2018)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/201129/WIR2_Payoff_195_B_NT_v70_A_Mech5_FS.jpg",
#                 "Showtimes": [
#                     "11:35a",
#                     "2:30p",
#                     "5:30p"
#                 ],
#                 "Title": "Ralph Breaks the Internet"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213524/GreenBook2018.jpg",
#                 "Showtimes": [
#                     "11:30a",
#                     "2:35p",
#                     "6:15p"
#                 ],
#                 "Title": "Green Book"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/211850/BoRhap_1Sht_VerB_View.jpg",
#                 "Showtimes": [
#                     "2:50p",
#                     "9:20p"
#                 ],
#                 "Title": "Bohemian Rhapsody"
#             }
#         ],
#         "Name": "Cinemark At Valley View and XD"
#     },
#     {
#         "Address": "1390 West 65th St., Cleveland, OH 44102",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213339/IfBealeStreetCouldTalk2018.jpg",
#                 "Showtimes": [],
#                 "Title": "If Beale Street Could Talk"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/212847/OTBOS_Final_One%20Sheet.jpg",
#                 "Showtimes": [],
#                 "Title": "On the Basis of Sex"
#             }
#         ],
#         "Name": "Capitol Theatre"
#     },
#     {
#         "Address": "230 Huron Road, Cleveland, OH 44113",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/196284/AdultLifeStills-Theatrical_small.jpg",
#                 "Showtimes": [],
#                 "Title": "Adult Life Skills\t"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/216258/Egg_KeyArt_18.jpg",
#                 "Showtimes": [],
#                 "Title": "Egg"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213141/Glass.jpg",
#                 "Showtimes": [],
#                 "Title": "Glass (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215170/dragonballzsuper-broly-400x600.jpg",
#                 "Showtimes": [],
#                 "Title": "Dragon Ball Super: Broly"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215000/ADogsWayHome2019.jpg",
#                 "Showtimes": [],
#                 "Title": "A Dog's Way Home"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/213339/IfBealeStreetCouldTalk2018.jpg",
#                 "Showtimes": [],
#                 "Title": "If Beale Street Could Talk"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/206497/Replicas2019.jpg",
#                 "Showtimes": [],
#                 "Title": "Replicas"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/214774/TheUpside2018.jpg",
#                 "Showtimes": [],
#                 "Title": "The Upside"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/215085/EscapeRoom2019.jpg",
#                 "Showtimes": [],
#                 "Title": "Escape Room (2019)"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208500/BB_Online_Dom_Payoff_1-Sheet_H-Steinfeld_BB_Bridge_Autobot.jpg",
#                 "Showtimes": [],
#                 "Title": "Bumblebee"
#             },
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images/MasterRepository/fandango/208293/SpiderManIntoTheSpiderVerse2018.jpg",
#                 "Showtimes": [],
#                 "Title": "Spider-Man: Into the Spider-Verse"
#             }
#         ],
#         "Name": "Tower City 11"
#     },
#     {
#         "Address": "601 Erieside Ave., Cleveland, OH 44114",
#         "Movies": [
#             {
#                 "Poster_URL": "//images.fandango.com/ImageRenderer/200/0/redesign/static/img/default_poster.png/0/images.fandango.com/ImageRenderer/100/0/redesign/static/img/default_poster.png/0/redesign/static/img/default_poster.png",
#                 "Showtimes": [],
#                 "Title": "The Great Barrier Reef"
#             }
#         ],
#         "Name": "DOME Theater at Great Lakes Science Center"
#     }
# ]

# %%
#Working code
theaters_movies = []
for i in range(0,len(theaters)):
    movies = theaters[i].find_all('li',class_='fd-movie')
    theater_movies = []
    movies_titles =[]
    movies_showtimes = []
    movies_posters = []
    for k in range(0,len(movies)):
        if movies[k].find('a',class_='dark'):
            movie_title = movies[k].find('a',class_='dark').text
        else:
            movie_title = movies[k].find('a',class_='dark')
        movies_titles.append(movie_title)
        if movies[k].find('img'):
            movie_poster = movies[k].find('img')['src']
        else:
            movie_poster = movies[k].find('img')
        movies_posters.append(movie_poster)
        movie_showtimes = []
        numshows=movies[k].find_all('a',class_='showtime-btn--available')
        for j in range(0,len(numshows)):
            showtime = numshows[j].text
            movie_showtimes.append(showtime)
        movies_showtimes.append(movie_showtimes)
        theater_movies.append({'Title':movies_titles[k],'Showtimes':movies_showtimes[k],'Poster_URL':movies_posters[k]})
    theaters_movies.append({'Movies':theater_movies})

# %%
#Find Theater
